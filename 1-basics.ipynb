# %% [markdown]
# ## Syntax and Semantics
# - single line and multiline comments
# - definition of syntax and semantics
# - Basic syntax rules
#
# Syntax refers to the set of rules that defines the combination of symbols that are considered to be correctly structured program in a language.
#
# Semantics refers to the meaning or the interpretation of symbols, characters, and commands in a language.

# %%
# This is single line comment 

'''
  This 
  is
  multiline
  comment
'''
## Multiline comments do not work in jupyter notebook files
# Out:
# '\n  This \n  is\n  multiline\n  comment\n'

# %%
# Basic syntax rules

# Python is case senditive.
# Python uses indentation to define a block of code.

# single statement on multiple lines (line continuation)
total = 10 + 20 + 30 +\
  40 + 50
print(total)
  
# multiple statement on a single line
x=1 ; y=2 ; z = x + y
print(z)

# Type Inference : using a single variable as mutiple type in a program 
var = 32 
print(type(var))

var = "name"
print(type(var))
# Out:
# 150
# 3
# <class 'int'>
# <class 'str'>
